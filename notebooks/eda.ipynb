# %%
import pandas as pd

# %%
df = pd.read_csv('../data/ods_jobs.csv')
df
# Out:
#          type                                               text       user  \
# 0     message  Привет!\n*Позиция:* Team Lead (Data science)\n...  U6X06R596
# 1     message  Эта вакансия для тех, кто хочет *решать соревн...  U0FF52P7D
# 2     message  *Компания:* Сбербанк\n*Вакансия:* Data Scienti...  UT1USB97U
# 3     message  ODS, привет!\n\nМы продолжаем поиски тимлида. ...  U4BSTMP1R
# 4     message  *Компания*: Сбербанк\n*Город*: Москва и если з...  U3XDRJZ9A
# ...       ...                                                ...        ...
# 2076  message  *Вакансия:* Deep Learner, Analyst\n\nМосква. М...  U5EJHML6M
# 2077  message  *Компания*: Everypixel (<https://labs.everypix...  U46T36RAA
# 2078  message  Всем привет\nМне нужен в команду в Х5 еще один...  U2LGQMC4D
# 2079  message  *Вакансия Data Scientist  в Розничный блок МТС...  U34SSE54G
# 2080  message  This is a vacancy from my friend Pawel, organi...  U0P95857C
#
#                 ts       team  user_team source_team  \
# ...
